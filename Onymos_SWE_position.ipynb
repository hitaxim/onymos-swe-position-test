# %%
import random
import threading
import time

# %%
# Constants for order types
BUY = "Buy"
SELL = "Sell"

# %%
# Order class to represent each order
class Order:
    def __init__(self, order_type, ticker, quantity, price):
        self.order_type = order_type
        self.ticker = ticker
        self.quantity = quantity
        self.price = price
        self.next = None

    def __repr__(self):
        return f"Order({self.order_type}, {self.ticker}, {self.quantity}, {self.price})"

# Node class for linked list implementation
class OrderNode:
    def __init__(self, order):
        self.order = order
        self.next = None

# %%
# StockOrderBook for handling Buy and Sell Orders for each ticker
class StockOrderBook:
    def __init__(self):
        self.buy_orders = None
        self.sell_orders = None

    def add_buy_order(self, order):
        # Insert buy orders in descending order of price
        new_node = OrderNode(order)
        if not self.buy_orders or self.buy_orders.order.price < order.price:
            new_node.next = self.buy_orders
            self.buy_orders = new_node
            print(f"Added Buy Order: {order}")
            return

        current = self.buy_orders
        while current.next and current.next.order.price >= order.price:
            current = current.next

        new_node.next = current.next
        current.next = new_node
        print(f"Added Buy Order: {order}")

    def add_sell_order(self, order):
        # Insert sell orders in ascending order of price
        new_node = OrderNode(order)
        if not self.sell_orders or self.sell_orders.order.price > order.price:
            new_node.next = self.sell_orders
            self.sell_orders = new_node
            print(f"Added Sell Order: {order}")
            return

        current = self.sell_orders
        while current.next and current.next.order.price <= order.price:
            current = current.next

        new_node.next = current.next
        current.next = new_node
        print(f"Added Sell Order: {order}")

    def match_orders(self):
        matched_orders = []
        # Matching buy and sell orders
        buy = self.buy_orders
        sell = self.sell_orders

        while buy and sell and buy.order.price >= sell.order.price:
            match_quantity = min(buy.order.quantity, sell.order.quantity)
            matched_orders.append((buy.order, sell.order, match_quantity))

            # Adjust quantities
            buy.order.quantity -= match_quantity
            sell.order.quantity -= match_quantity

            if buy.order.quantity == 0:
                self.buy_orders = buy.next
            if sell.order.quantity == 0:
                self.sell_orders = sell.next

            buy = self.buy_orders
            sell = self.sell_orders

        return matched_orders

# %%
# Global dictionary to store order books for each ticker
stock_order_books = {f"Ticker{i}": StockOrderBook() for i in range(1, 1025)}

# %%
# StockTradingEngine for adding orders and matching them
class StockTradingEngine:
    def __init__(self):
        self.lock = threading.Lock()

    def add_order(self, order_type, ticker, quantity, price):
        """ Adds order to the order book and attempts to match the orders. """
        with self.lock:
            order = Order(order_type, ticker, quantity, price)
            order_book = stock_order_books[ticker]

            if order_type == BUY:
                order_book.add_buy_order(order)
            elif order_type == SELL:
                order_book.add_sell_order(order)

            self.match_orders(ticker)

    def match_orders(self, ticker):
        """ Match buy and sell orders for a given ticker. """
        order_book = stock_order_books[ticker]
        matched_orders = order_book.match_orders()

        for buy_order, sell_order, quantity in matched_orders:
            print(f"Matched {quantity} units of {buy_order.ticker} at {buy_order.price} (Buy) and {sell_order.price} (Sell)")

# Function to simulate adding orders randomly
def add_order(engine):
    order_type = random.choice([BUY, SELL])
    ticker = f"Ticker{random.randint(1, 1024)}"
    quantity = random.randint(1, 100)
    price = random.uniform(10, 1000)

    engine.add_order(order_type, ticker, quantity, price)

# Wrapper function to simulate random stock orders being placed and matched
def simulate_stock_market(engine):
    while True:
        # Randomly add an order
        add_order(engine)

        # Sleep for a random interval to simulate real-time market
        time.sleep(random.uniform(0.1, 1))

# %%
# Start the simulation in a separate thread
if __name__ == "__main__":
    engine = StockTradingEngine()
    threading.Thread(target=simulate_stock_market, args=(engine,), daemon=True).start()

    # Keep the main thread alive to simulate the market
    while True:
        time.sleep(1)
# Out:
# Added Sell Order: Order(Sell, Ticker119, 81, 272.8001942620634)
# Added Sell Order: Order(Sell, Ticker717, 34, 604.0297324374169)
# Added Buy Order: Order(Buy, Ticker303, 1, 852.5205279881646)
# Added Buy Order: Order(Buy, Ticker37, 98, 513.8570016770798)
# Added Sell Order: Order(Sell, Ticker948, 62, 478.77936973928433)
# Added Buy Order: Order(Buy, Ticker901, 35, 493.434382414578)
# Added Sell Order: Order(Sell, Ticker677, 31, 659.5184995192046)
# Added Sell Order: Order(Sell, Ticker211, 37, 410.32755090878004)
# Added Buy Order: Order(Buy, Ticker514, 20, 664.4177702137406)
# Added Sell Order: Order(Sell, Ticker833, 52, 931.9979601165032)
# Added Sell Order: Order(Sell, Ticker1011, 62, 742.6777750119109)
# Added Buy Order: Order(Buy, Ticker827, 55, 495.369813456694)
# Added Sell Order: Order(Sell, Ticker162, 78, 579.329345553979)
# Added Buy Order: Order(Buy, Ticker107, 59, 420.55862236215603)
# Added Buy Order: Order(Buy, Ticker550, 98, 754.5718043400111)
# Added Buy Order: Order(Buy, Ticker692, 41, 126.85237955703602)
# Added Buy Order: Order(Buy, Ticker1016, 35, 228.9518722501631)
# Added Sell Order: Order(Sell, Ticker232, 52, 119.28382878361657)
# Added Buy Order: Order(Buy, Ticker524, 77, 320.7176370890726)
# Added Buy Order: Order(Buy, Ticker251, 6, 132.3953094604872)
# Added Sell Order: Order(Sell, Ticker619, 53, 952.7750382990906)
# Added Buy Order: Order(Buy, Ticker268, 44, 56.11690472506897)
# Added Buy Order: Order(Buy, Ticker135, 88, 446.53137237252264)
# Added Buy Order: Order(Buy, Ticker620, 16, 155.90981780927066)
# Added Sell Order: Order(Sell, Ticker127, 32, 896.1013730699087)
# Added Buy Order: Order(Buy, Ticker646, 78, 35.952754507745354)
# Added Buy Order: Order(Buy, Ticker849, 42, 772.7483330876314)
# Added Sell Order: Order(Sell, Ticker949, 59, 501.4871276170148)
# Added Buy Order: Order(Buy, Ticker381, 88, 500.0738675421139)
# Added Sell Order: Order(Sell, Ticker531, 44, 70.69015468939989)
# Added Buy Order: Order(Buy, Ticker287, 69, 627.8753833981718)
# Added Sell Order: Order(Sell, Ticker834, 41, 467.3521268332422)
# Added Buy Order: Order(Buy, Ticker220, 51, 737.823455031428)
# Added Buy Order: Order(Buy, Ticker981, 70, 599.2061511095575)
# Added Buy Order: Order(Buy, Ticker275, 51, 752.8056161772722)
# Added Buy Order: Order(Buy, Ticker200, 52, 842.7338969932553)
# Added Sell Order: Order(Sell, Ticker812, 12, 470.81553648012607)
# Added Buy Order: Order(Buy, Ticker934, 4, 435.9494179646686)
# Added Sell Order: Order(Sell, Ticker245, 46, 671.7754954499198)
# Added Sell Order: Order(Sell, Ticker71, 68, 436.37147330071423)
# Added Sell Order: Order(Sell, Ticker104, 96, 485.95756262829053)
# Added Buy Order: Order(Buy, Ticker557, 34, 139.30809905771773)
# Added Sell Order: Order(Sell, Ticker936, 84, 468.001467697564)
# Added Buy Order: Order(Buy, Ticker994, 74, 758.9843781169116)
# Added Sell Order: Order(Sell, Ticker396, 1, 848.8640733693982)
# Added Buy Order: Order(Buy, Ticker574, 68, 849.6128875729967)
# Added Buy Order: Order(Buy, Ticker523, 19, 773.0709248825082)
# Added Buy Order: Order(Buy, Ticker276, 8, 518.2633004592278)
# Added Buy Order: Order(Buy, Ticker918, 78, 456.62663400093174)
# Added Sell Order: Order(Sell, Ticker224, 5, 777.4789630732951)
# Added Buy Order: Order(Buy, Ticker797, 57, 510.42792942583566)
# Added Sell Order: Order(Sell, Ticker734, 66, 280.7626990912944)
# Added Sell Order: Order(Sell, Ticker755, 21, 757.6985397560796)
# Added Sell Order: Order(Sell, Ticker665, 24, 485.9433713115987)
# Added Buy Order: Order(Buy, Ticker236, 90, 974.5657556269799)
# Added Sell Order: Order(Sell, Ticker532, 50, 265.28615913004126)
# Added Sell Order: Order(Sell, Ticker623, 29, 745.3182289633892)
# Added Sell Order: Order(Sell, Ticker405, 54, 496.4021374476976)
# Added Buy Order: Order(Buy, Ticker977, 19, 394.50113027235756)
# Added Sell Order: Order(Sell, Ticker97, 87, 947.5355574823009)
# Added Buy Order: Order(Buy, Ticker897, 21, 530.4559776445461)
# Added Buy Order: Order(Buy, Ticker589, 67, 403.60187492068286)
# Added Sell Order: Order(Sell, Ticker224, 17, 958.9675386325522)
# Added Sell Order: Order(Sell, Ticker810, 47, 487.56239393763644)
# Added Buy Order: Order(Buy, Ticker910, 89, 380.8906076531114)
# Added Sell Order: Order(Sell, Ticker293, 6, 837.3117969602806)
# Added Sell Order: Order(Sell, Ticker986, 4, 316.6795405766359)
# Added Sell Order: Order(Sell, Ticker4, 40, 83.4427081086499)
# Added Buy Order: Order(Buy, Ticker780, 72, 511.278978159752)
# Added Sell Order: Order(Sell, Ticker598, 30, 410.73657354849604)
# Added Buy Order: Order(Buy, Ticker177, 6, 464.24136606582147)
# Added Sell Order: Order(Sell, Ticker410, 85, 572.8210858173711)
# Added Buy Order: Order(Buy, Ticker725, 28, 550.9215854816247)
# Added Buy Order: Order(Buy, Ticker757, 2, 181.47129667810506)
# Added Buy Order: Order(Buy, Ticker99, 56, 814.3436104993268)
# Added Buy Order: Order(Buy, Ticker429, 61, 515.2686471906189)
# Added Sell Order: Order(Sell, Ticker476, 55, 570.893412547996)
# Added Buy Order: Order(Buy, Ticker725, 8, 348.1157230608409)
# Added Buy Order: Order(Buy, Ticker872, 83, 382.4048428832078)
# Added Buy Order: Order(Buy, Ticker448, 86, 338.38038465079296)
# Added Sell Order: Order(Sell, Ticker592, 78, 769.5891306850334)
# Added Buy Order: Order(Buy, Ticker388, 85, 490.59416574770637)
# Added Buy Order: Order(Buy, Ticker796, 46, 78.87116701016578)
# Added Buy Order: Order(Buy, Ticker859, 26, 683.5526003123092)
# Added Sell Order: Order(Sell, Ticker87, 71, 442.35227045965274)
# Added Sell Order: Order(Sell, Ticker899, 90, 272.2290603925014)
# Added Buy Order: Order(Buy, Ticker854, 77, 770.3824650215985)
# Added Sell Order: Order(Sell, Ticker976, 5, 54.5707694619628)
# Added Buy Order: Order(Buy, Ticker523, 23, 956.6689728538743)
# Added Buy Order: Order(Buy, Ticker443, 43, 444.7885701959521)
# Added Sell Order: Order(Sell, Ticker750, 34, 393.5157858575929)
# Added Sell Order: Order(Sell, Ticker448, 6, 924.2909573762884)
# Added Sell Order: Order(Sell, Ticker725, 72, 635.9681840468675)
# Added Buy Order: Order(Buy, Ticker381, 53, 82.43829872569304)
# Added Buy Order: Order(Buy, Ticker412, 42, 437.470847190706)
# Added Sell Order: Order(Sell, Ticker695, 21, 25.856744319260866)
# Added Sell Order: Order(Sell, Ticker1016, 50, 237.59609422774506)
# Added Sell Order: Order(Sell, Ticker992, 20, 467.54873164959366)
# Added Sell Order: Order(Sell, Ticker386, 72, 81.6856139259202)
# Added Sell Order: Order(Sell, Ticker10, 38, 58.72669570382867)
# Added Sell Order: Order(Sell, Ticker410, 68, 717.9630495034213)
# Added Buy Order: Order(Buy, Ticker25, 64, 962.0519533292363)
# Added Sell Order: Order(Sell, Ticker927, 88, 994.7755212601271)
# Added Sell Order: Order(Sell, Ticker273, 53, 144.4193547747418)
# Added Sell Order: Order(Sell, Ticker793, 2, 627.6778585499916)
# Added Sell Order: Order(Sell, Ticker485, 31, 875.1774107854125)
# Added Buy Order: Order(Buy, Ticker193, 97, 653.5450471197072)
# Added Buy Order: Order(Buy, Ticker112, 51, 387.575667523229)
# Added Buy Order: Order(Buy, Ticker203, 50, 742.0837931532507)
# Added Buy Order: Order(Buy, Ticker617, 33, 637.9789236945442)
# Added Sell Order: Order(Sell, Ticker516, 51, 32.57907505199927)
# Added Buy Order: Order(Buy, Ticker616, 38, 324.45061802794805)
# Added Sell Order: Order(Sell, Ticker17, 71, 426.291303676865)
# Added Sell Order: Order(Sell, Ticker53, 46, 904.2679370065171)
# Added Buy Order: Order(Buy, Ticker395, 56, 720.2631684972414)
# Added Buy Order: Order(Buy, Ticker830, 32, 731.2590503764601)
# Added Buy Order: Order(Buy, Ticker893, 98, 703.0397334786853)
# Added Sell Order: Order(Sell, Ticker364, 1, 176.49100164483272)
# Added Sell Order: Order(Sell, Ticker826, 57, 702.7100935241893)
# Added Buy Order: Order(Buy, Ticker165, 53, 456.3984690582464)
# Added Buy Order: Order(Buy, Ticker618, 14, 972.0646007739851)
# Added Buy Order: Order(Buy, Ticker57, 64, 986.0419561601425)
# Added Sell Order: Order(Sell, Ticker1005, 2, 709.6391632802997)
# Added Sell Order: Order(Sell, Ticker314, 10, 326.87405432323635)
# Added Sell Order: Order(Sell, Ticker305, 96, 316.24236992547884)
# Added Buy Order: Order(Buy, Ticker211, 71, 972.5387934973522)
# Matched 37 units of Ticker211 at 972.5387934973522 (Buy) and 410.32755090878004 (Sell)
# Added Buy Order: Order(Buy, Ticker798, 46, 212.68488337348498)
# Added Sell Order: Order(Sell, Ticker97, 79, 303.96142068356124)
# Added Sell Order: Order(Sell, Ticker149, 18, 112.10820587596233)
# Added Sell Order: Order(Sell, Ticker70, 64, 686.571507131963)
# Added Sell Order: Order(Sell, Ticker589, 92, 478.11210228822097)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-09a1e2ebae86> in <cell line: 0>()
#       6     # Keep the main thread alive to simulate the market
#       7     while True:
# ----> 8         time.sleep(1)
#
# KeyboardInterrupt:
